# %%
# Create Node
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

# Create constructor

class Stack:
    def __init__(self, value):
        new_node = Node(value)
        self.top = new_node
        self.bottom = new_node
        self.height = 1


# Print 
    def print_stack(self):
        temp = self.top
        while temp is not None:
            print(temp.value)
            temp = temp.next

# create push method
    def push(self,value):
        new_node = Node(value)
        if self.height == 0:
            self.top = new_node
        else:
            new_node.next = self.top
            self.top = new_node 
        self.height += 1

# Pop Method

    def pop(self):
        if self.height == 0:
         return None
        else:
            temp = self.top
            self.top = self.top.next
            temp.next = None
            self.height -= 1
            return temp.value



my_stack = Stack(1)
my_stack.push(2)
my_stack.push(3)
my_stack.push(4)
my_stack.push(5)
my_stack.pop()

my_stack.print_stack()
# Out:
# 4
# 3
# 2
# 1

# %% [markdown]
# ### **Stack | Push operation**

# %%
#  Push 

stack = []

stack.append(1)
stack.append(2)
stack.append(3)
print(stack)
stack.insert(0, 3) #index = 0 , value = 3
print(stack)
# Out:
# [1, 2, 3]
# [3, 1, 2, 3]

# %% [markdown]
# ## **Pop operation**

# %%
stack.pop(0)
print(stack)
# Out:
# [1, 2, 3]

# %% [markdown]
# ## **isEmpty()**

# %%
def isEmpty(stack):
    if stack == 0:
        return True
    else:
        return False
    
isEmpty(stack)
# Out:
# False

# %% [markdown]
# ## **isFull()**

# %%
maxSize = len(stack)
print(maxSize)

def isFull(stack):
    if len(stack) == maxSize:
        return True
    else:
        return False
# Out:
# 3
